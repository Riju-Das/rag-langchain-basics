# %% [markdown]
# ### Data Ingestion

# %%
### Document Data Structure
from langchain_core.documents import Document

doc = Document(
    page_content = "This is main page content",
    metadata= {
        "source" : "example.txt",
        "pages": 1,
        "author": "Riju Das",
        "date_created":"2025-01-01"

    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Riju Das', 'date_created': '2025-01-01'}, page_content='This is main page content')

# %%
### create a simple text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text= {
        "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems


    """
}
for filepath,content in sample_text.items():
    with open(filepath, 'w', encoding = "utf-8") as f:
        f.write(content)
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
###textloader
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
doc = loader.load()
print(doc)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### directory loader
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",  ##Pattern to match
    loader_cls=TextLoader, ##loader class
    loader_kwargs={'encoding':'utf-8'}, ##loader class kwargs
    show_progress=False
)
doc = dir_loader.load()
doc
# Out:
# [Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
## pdf loader
from langchain_community.document_loaders import PyMuPDFLoader
dir_loader = DirectoryLoader(
    "../data/pdf", #no pdf in the directory so emply list
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
pdfdoc = dir_loader.load()
print(pdfdoc)
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': 'anonymous', 'creationdate': '2026-03-28T15:59:08+05:00', 'source': '../data/pdf/doc_03_prompting_and_guardrails.pdf', 'file_path': '../data/pdf/doc_03_prompting_and_guardrails.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'Prompting, Citations, and Guardrails in RAG', 'author': 'anonymous', 'subject': 'unspecified', 'keywords': '', 'moddate': '2026-03-28T15:59:08+05:00', 'trapped': '', 'modDate': "D:20260328155908+05'00'", 'creationDate': "D:20260328155908+05'00'", 'page': 0}, page_content='Prompting, Citations, and Guardrails in RAG\nA RAG prompt should clearly instruct the model to answer using only the provided context and\nto say "I don\'t know" when the context does not contain enough information.\nCitations improve trust and make debugging easier. If you store metadata like filename and\nchunk id, you can include citations in the final answer by listing which chunks were used.\nCommon failure mode: the model blends its prior knowledge with retrieved context. Guardrails\ninclude: (1) strict system instructions, (2) answer format constraints, (3) refusing to answer\nwithout evidence, and (4) post-answer verification using another model or rule-based checks.\nSecurity note: treat retrieved text as untrusted input. Prompt injection can occur inside\ndocuments. Consider filtering suspicious instructions from documents and using a separate,\nlocked system prompt that overrides any document content.'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': 'anonymous', 'creationdate': '2026-03-28T15:59:08+05:00', 'source': '../data/pdf/doc_02_vector_databases.pdf', 'file_path': '../data/pdf/doc_02_vector_databases.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'Vector Databases and Similarity Search', 'author': 'anonymous', 'subject': 'unspecified', 'keywords': '', 'moddate': '2026-03-28T15:59:08+05:00', 'trapped': '', 'modDate': "D:20260328155908+05'00'", 'creationDate': "D:20260328155908+05'00'", 'page': 0}, page_content='Vector Databases and Similarity Search\nA vector database stores embeddings (dense numeric vectors) for documents or chunks. The\ngoal is to quickly find vectors that are close to a query vector using a similarity metric such as\ncosine similarity or dot product.\nIndex structures (e.g., HNSW) trade perfect accuracy for speed and memory efficiency. For\nmany RAG workloads, approximate nearest-neighbor search is sufficient and dramatically faster\nthan brute force.\nGood practice: normalize text before embedding (remove boilerplate, keep headings), and keep\nchunk-level metadata so you can filter results by topic, file type, or recency. Hybrid search\n(keyword + vector) can improve results for proper nouns and code symbols.\nWhen debugging: print the top-k retrieved chunks and verify they contain the answer. If not, the\nissue is often in document loading, chunk boundaries, or missing coverage in your corpus.'), Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': 'anonymous', 'creationdate': '2026-03-28T15:59:08+05:00', 'source': '../data/pdf/doc_01_rag_and_langchain.pdf', 'file_path': '../data/pdf/doc_01_rag_and_langchain.pdf', 'total_pages': 1, 'format': 'PDF 1.3', 'title': 'RAG + LangChain: Practical Notes', 'author': 'anonymous', 'subject': 'unspecified', 'keywords': '', 'moddate': '2026-03-28T15:59:08+05:00', 'trapped': '', 'modDate': "D:20260328155908+05'00'", 'creationDate': "D:20260328155908+05'00'", 'page': 0}, page_content="RAG + LangChain: Practical Notes\nRetrieval-Augmented Generation (RAG) improves LLM answers by grounding generation in\nexternal documents. Instead of relying only on the model's parameters, a retriever selects\nrelevant chunks from a knowledge base and passes them to the LLM as context.\nIn LangChain, a typical pipeline has: (1) document loading, (2) text splitting, (3) embeddings, (4)\nvector store indexing, and (5) a retrie ...

# %%
type(pdfdoc[0])
# Out:
# langchain_core.documents.base.Document
